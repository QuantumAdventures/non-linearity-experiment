# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../../data/electronics/passive_bandpass.txt', sep='\t', encoding='ISO-8859-1')
df.head()
# Out:
#       Freq.                                          V(n002)
# 0  1.000000  (-6.79879847744457e+01dB,1.78919873827804e+02°)
# 1  1.002305  (-6.79479903129748e+01dB,1.78917384274230e+02°)
# 2  1.004616  (-6.79079958770616e+01dB,1.78914888984374e+02°)
# 3  1.006932  (-6.78680014668243e+01dB,1.78912387945034e+02°)
# 4  1.009253  (-6.78280070823811e+01dB,1.78909881142974e+02°)

# %%
df['mag'] = df['V(n002)'].apply(lambda x: float(x.split(',')[0][1:-2]))
df['phase'] = df['V(n002)'].apply(lambda x: float(x.split(',')[1][:-2]))

# %%
df.head()
# Out:
#       Freq.                                          V(n002)        mag  \
# 0  1.000000  (-6.79879847744457e+01dB,1.78919873827804e+02°) -67.987985
# 1  1.002305  (-6.79479903129748e+01dB,1.78917384274230e+02°) -67.947990
# 2  1.004616  (-6.79079958770616e+01dB,1.78914888984374e+02°) -67.907996
# 3  1.006932  (-6.78680014668243e+01dB,1.78912387945034e+02°) -67.868001
# 4  1.009253  (-6.78280070823811e+01dB,1.78909881142974e+02°) -67.828007
#
#         phase
# 0  178.919874
# 1  178.917384
# 2  178.914889
# 3  178.912388
# 4  178.909881

# %%
fig, ax1 = plt.subplots()

plt.rcParams.update({'font.size': 18})
plt.rcParams["axes.linewidth"] = 2
color = 'tab:red'
ax1.set_xlabel('Freq (Hz)')
ax1.grid(True, which="both", ls="-")
ax1.set_ylabel('Mag (dB)')
ax1.plot(df['Freq.'], df['mag'], color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('Phase (˚)')
ax2.set_xscale('log')
ax2.plot(df['Freq.'], df['phase'], color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_xlim([1e0, 1e6])
fig.tight_layout()
plt.show()

# %%
def pre_process_simulation(df, columns, signals, new_columns):
    df = df[columns]
    for i, column in enumerate(new_columns):
        df[column] = df[signals[i]]
    for signal in new_columns:
        df[f'mag_{signal}'] = df[signal].apply(lambda x: float(x[1:-1].split(',')[0][:-2]))
        df[f'phase_{signal}'] = df[signal].apply(lambda x: float(x[1:-1].split(',')[1][:-1]))
    df = df.drop(new_columns, axis=1)
    df = df.drop(signals, axis=1)
    df['phase_complete_filter'][:107] = -df['phase_complete_filter'][:107]
    df['phase_complete_filter'][-99:] = -df['phase_complete_filter'][-99:]
    return df

# %%
df = pd.read_csv('../../data/electronics/complete_active_bandpass.txt', sep='\t', encoding='ISO-8859-1')
df['mag'] = df['V(n011)'].apply(lambda x: float(x.split(',')[0][1:-2]))
df['phase'] = df['V(n011)'].apply(lambda x: float(x.split(',')[1][:-2]))
df['phase'][:5070] = 360+df['phase'][:5070]
df['phase'][-981:] = -360+df['phase'][-981:]
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'V(n011)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_498534/2564249172.py in <module>
#       1 df = pd.read_csv('../../data/electronics/complete_active_bandpass.txt', sep='\t', encoding='ISO-8859-1')
# ----> 2 df['mag'] = df['V(n011)'].apply(lambda x: float(x.split(',')[0][1:-2]))
#       3 df['phase'] = df['V(n011)'].apply(lambda x: float(x.split(',')[1][:-2]))
#       4 df['phase'][:5070] = 360+df['phase'][:5070]
#       5 df['phase'][-981:] = -360+df['phase'][-981:]
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'V(n011)'

# %%
fig, ax1 = plt.subplots()

plt.rcParams.update({'font.size': 18})
plt.rcParams["axes.linewidth"] = 2
color = 'tab:red'
ax1.set_xlabel('Freq (Hz)')
ax1.grid(True, which="both", ls="-")
ax1.set_ylabel('Mag (dB)')
ax1.plot(df['Freq.'],df['mag'], color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim([-100, 25])

ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('Phase (˚)')
ax2.set_xscale('log')
ax2.plot(df['Freq.'], df['phase'], color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_xlim([1e3, 1e6])
ax2.set_ylim([-200, 200])
fig.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mag'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_498534/1867144668.py in <module>
#       7 ax1.grid(True, which="both", ls="-")
#       8 ax1.set_ylabel('Mag (dB)')
# ----> 9 ax1.plot(df['Freq.'],df['mag'], color=color)
#      10 ax1.tick_params(axis='y', labelcolor=color)
#      11 ax1.set_ylim([-100, 25])
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'mag'
